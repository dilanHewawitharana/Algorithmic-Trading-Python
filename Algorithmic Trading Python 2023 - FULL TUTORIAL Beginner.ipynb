#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# ...

# %%
# convert tuple to multi Index
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.478997  18.498020   87.129944    7.643214  28.520000
# 2010-01-05    6.490201  18.274250   87.360573    7.656429  28.174999
# 2010-01-06    6.386965  18.267769   87.422112    7.534643  28.165001
# 2010-01-07    6.375158  18.222357   87.791138    7.520714  28.094999
# 2010-01-08    6.417542  17.885096   88.083298    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.679749  48.779110  352.967987  131.970001  53.439999
# 2020-12-28  134.317795  49.436317  356.000305  136.690002  54.160000
# 2020-12-29  132.529388  49.408924  355.321136  134.869995  54.130001
# 2020-12-30  131.399368  49.691891  355.828125  133.720001  54.439999
# 2020-12-31  130.387222  50.057003  357.636017  132.690002  54.840000
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
# Describe
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     31.562566    32.208758   182.052368    33.777537    41.320121
# std      24.614793     8.183724    69.703575    24.572747     6.808527
# min       5.814175    16.373821    79.271935     6.858929    25.014999
# 25%      15.201320    26.605545   114.881287    17.484285    37.660000
# 50%      24.549250    31.768915   175.981033    26.987499    41.759998
# 75%      40.931637    37.628521   241.932739    43.007500    45.549999
# max     134.317795    53.069550   357.636017   136.690002    60.130001
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# ...

# %%
# show only close values
close = stocks.loc[:, "Close"].copy()
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# C:\Users\dilan\AppData\Local\Temp\ipykernel_9688\715908909.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
close.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=18)
plt.show()

# %%
# 1st raw, 1st col and 1st raw , 2nd col
close.iloc[0,0], close.iloc[0,1]
# Out:
# (7.643214225769043, 28.520000457763672)

# %%
close.AAPL
# Out:
# Date
# 2010-01-04      7.643214
# 2010-01-05      7.656429
# 2010-01-06      7.534643
# 2010-01-07      7.520714
# 2010-01-08      7.570714
#                  ...
# 2020-12-24    131.970001
# 2020-12-28    136.690002
# 2020-12-29    134.869995
# 2020-12-30    133.720001
# 2020-12-31    132.690002
# Name: AAPL, Length: 2769, dtype: float64

# %%
# Normalize by deviding by the lowest value which is the 1st value
close.AAPL.div(close.iloc[0,0])
# Out:
# Date
# 2010-01-04     1.000000
# 2010-01-05     1.001729
# 2010-01-06     0.985795
# 2010-01-07     0.983973
# 2010-01-08     0.990514
#                 ...
# 2020-12-24    17.266296
# 2020-12-28    17.883838
# 2020-12-29    17.645717
# 2020-12-30    17.495258
# 2020-12-31    17.360498
# Name: AAPL, Length: 2769, dtype: float64

# %%
# Normalize value start from 100
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2020-12-24    1726.629626
# 2020-12-28    1788.383766
# 2020-12-29    1764.571699
# 2020-12-30    1749.525753
# 2020-12-31    1736.049763
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL      7.643214
# KO       28.520000
# SPY     113.330002
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
# Normalize all close values by deviding each column 1st value
normClose = close.div(close.iloc[0]).mul(100)
normClose
# Out:
#                    AAPL          KO         SPY
# Date
# 2010-01-04   100.000000  100.000000  100.000000
# 2010-01-05   100.172893   98.790318  100.264710
# 2010-01-06    98.579511   98.755261  100.335302
# 2010-01-07    98.397266   98.509814  100.758846
# 2010-01-08    99.051443   96.686537  101.094148
# ...                 ...         ...         ...
# 2020-12-24  1726.629626  187.377271  325.597806
# 2020-12-28  1788.383766  189.901820  328.394959
# 2020-12-29  1764.571699  189.796635  327.768451
# 2020-12-30  1749.525753  190.883583  328.236111
# 2020-12-31  1736.049763  192.286112  329.903820
#
# [2769 rows x 3 columns]

# %%
normClose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=18)
plt.show()

# %%
# copy the AAPL values from close and convert into data frame
aapl = close.AAPL.copy().to_frame()
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
# Shift aapl column by 1
#aapl.shift(periods=1)
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04         NaN         NaN
# 2010-01-05    7.643214         NaN
# 2010-01-06    7.656429    7.643214
# 2010-01-07    7.534643    7.656429
# 2010-01-08    7.520714    7.534643
# ...                ...         ...
# 2020-12-24  130.960007  131.880005
# 2020-12-28  131.970001  130.960007
# 2020-12-29  136.690002  131.970001
# 2020-12-30  134.869995  136.690002
# 2020-12-31  133.720001  134.869995
#
# [2769 rows x 2 columns]

# %%
# shift aapl column by 1 and store into lag1 column
aapl["lag1"]=aapl.shift(periods=1)
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2769 rows x 2 columns]

# %%
# subtract AAPL value by lag1 value
aapl["Diff"]=aapl.AAPL.sub(aapl.lag1)
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2020-12-24  131.970001  130.960007  1.009995
# 2020-12-28  136.690002  131.970001  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999
#
# [2769 rows x 3 columns]

# %%
aapl["% Change"]=aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995    0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001    3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007   -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994   -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999   -0.770265
#
# [2769 rows x 6 columns]

# %%
# Diff2 shows the difference happens by one day
aapl["Diff2"]=aapl.AAPL.diff(periods=1)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.050000
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.007712  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  1.035766  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297 -1.029999
#
# [2769 rows x 5 columns]

# %%
# % change 2 shows the percentage diff happens by one day
aapl["% change 2"]=aapl.AAPL.pct_change(periods=1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995    0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001    3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007   -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994   -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999   -0.770265
#
# [2769 rows x 6 columns]

# %%
# Delete column
del aapl["lag1"]
del aapl["Diff"]
del aapl["% Change"]
del aapl["Diff2"]
aapl
# Out:
#                   AAPL  % change 2
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    0.172893
# 2010-01-06    7.534643   -1.590632
# 2010-01-07    7.520714   -0.184871
# 2010-01-08    7.570714    0.664833
# ...                ...         ...
# 2020-12-24  131.970001    0.771224
# 2020-12-28  136.690002    3.576571
# 2020-12-29  134.869995   -1.331485
# 2020-12-30  133.720001   -0.852668
# 2020-12-31  132.690002   -0.770265
#
# [2769 rows x 2 columns]

# %%
# rename column
aapl.rename(columns = {'% change 2':'Change'}, inplace=True)
aapl
# Out:
#                   AAPL    Change
# Date
# 2010-01-04    7.643214       NaN
# 2010-01-05    7.656429  0.172893
# 2010-01-06    7.534643 -1.590632
# 2010-01-07    7.520714 -0.184871
# 2010-01-08    7.570714  0.664833
# ...                ...       ...
# 2020-12-24  131.970001  0.771224
# 2020-12-28  136.690002  3.576571
# 2020-12-29  134.869995 -1.331485
# 2020-12-30  133.720001 -0.852668
# 2020-12-31  132.690002 -0.770265
#
# [2769 rows x 2 columns]

# %%
# resample data with respect to month
aapl.AAPL.resample("M").last()
# Out:
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-31    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: M, Name: AAPL, Length: 132, dtype: float64

# %%
# resample data with respect business day for of month
aapl.AAPL.resample("BM").last()
# Out:
# Date
# 2010-01-29      6.859286
# 2010-02-26      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-30    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: BM, Name: AAPL, Length: 132, dtype: float64

# %%
# resample data with respect business day for of month, percentage change happens per each month
aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2020-08-31    21.437974
# 2020-09-30   -10.252632
# 2020-10-30    -6.001206
# 2020-11-30     9.360649
# 2020-12-31    11.457370
# Freq: BM, Name: AAPL, Length: 132, dtype: float64

# %%
del aapl["Change"]
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
# calculate percentage chage and drop NAN values if exist
ret = aapl.pct_change().dropna()
ret
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008821
# ...              ...
# 2020-12-24  0.007712
# 2020-12-28  0.035766
# 2020-12-29 -0.013315
# 2020-12-30 -0.008527
# 2020-12-31 -0.007703
#
# [2768 rows x 1 columns]

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2768 entries, 2010-01-05 to 2020-12-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2768 non-null   float64
# dtypes: float64(1)
# memory usage: 43.2 KB

# %%
# plot histogram
ret.plot(kind="hist", figsize=(12,8), bins=100)
plt.show()

# %%
# calculate mean
daily_mean_ret = ret.mean()
daily_mean_ret
# Out:
# AAPL    0.001191
# dtype: float64

# %%
# calculate variance
var_daily = ret.var()
var_daily
# Out:
# AAPL    0.000318
# dtype: float64

# %%
# standard deviation
std_daily = np.sqrt(var_daily)
std_daily
# Out:
# AAPL    0.017843
# dtype: float64

# %%
# Another way to caculate standard variation
std_daily2 = ret.std()
std_daily2
# Out:
# AAPL    0.017843
# dtype: float64

# %%
# calculate annual mean return
annual_mean_ret=daily_mean_ret*252
annual_mean_ret
# Out:
# AAPL    0.300134
# dtype: float64

# %%
# calculate annual var return
annual_var_ret=var_daily*252
annual_var_ret
# Out:
# AAPL    0.080226
# dtype: float64

# %%
# calculate annual std return
annual_std_ret=np.sqrt(annual_var_ret)
annual_std_ret
# Out:
# AAPL    0.283242
# dtype: float64

# %%
# another way to calculate annual std return
ret.std()*np.sqrt(252)
# Out:
# AAPL    0.283242
# dtype: float64
